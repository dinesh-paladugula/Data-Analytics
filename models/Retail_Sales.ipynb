# %% [markdown]
# # Project: 1
# Assignment for the Mini Project: Retail Sales Dataset

# %% [raw]
# Objective:
# Analyze the retail dataset to uncover trends, insights, and correlations.
# Assignment Task
# Data Loading and Inspection
# 1.	Load the dataset into a Pandas DataFrame.
# 2.	Display the first 10 rows of the dataset.
# 3.	Print the column names and their respective data types.
# 4.	Check for missing values and duplicates in the dataset. How would you handle them?

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"E:\Data-Analytics\data\retail_sales_dataset.csv")
df
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.head(10)
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
# 5               6  2023-04-25     CUST006  Female   45           Beauty
# 6               7  2023-03-13     CUST007    Male   46         Clothing
# 7               8  2023-02-22     CUST008    Male   30      Electronics
# 8               9  2023-12-13     CUST009    Male   63      Electronics
# 9              10  2023-10-07     CUST010  Female   52         Clothing
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %% [raw]
# There are no missing values and duplicate values.

# %% [raw]
# Exploratory Data Analysis (EDA)
# 1.	Plot the distribution of the following discrete features:
#     o	Quantity
#     o	Category
# 2.	Identify the most frequently purchased product category.

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
df['Quantity'].plot.hist()
plt.show()

# %%
df['Product Category'].value_counts().plot.bar()
plt.title('Bar chart depicting the frequency of each product category')
plt.xticks(rotation=0)
plt.show()

# %% [raw]
# Timestamp Transformation
# 1.	Convert the Order Date column to a datetime format.
# 2.	Create new columns:
#     o	Day of the week.
#     o	Day of the month.
#     o	Month.
#     o	Year.
#     o	Season (Winter, Spring, Summer, Fall).
# 3.	Set the Order Date column as the DataFrame index

# %%
df['Order Date'] = pd.to_datetime(df['Date'])
df['Order Date']
# Out:
# 0     2023-11-24
# 1     2023-02-27
# 2     2023-01-13
# 3     2023-05-21
# 4     2023-05-06
#          ...
# 995   2023-05-16
# 996   2023-11-17
# 997   2023-10-29
# 998   2023-12-05
# 999   2023-04-12
# Name: Order Date, Length: 1000, dtype: datetime64[ns]

# %%
weekdays = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}
df['Day of the Week'] = df['Order Date'].dt.dayofweek.map(weekdays)
df['Day of the Week']
# Out:
# 0         Friday
# 1         Monday
# 2         Friday
# 3         Sunday
# 4       Saturday
#          ...
# 995      Tuesday
# 996       Friday
# 997       Sunday
# 998      Tuesday
# 999    Wednesday
# Name: Day of the Week, Length: 1000, dtype: object

# %%
Months = {
    1: 'January',
    2: 'February',
    3: 'March',
    4: 'April',
    5: 'May',
    6: 'June',
    7: 'July',
    8: 'August',
    9: 'September',
    10: 'October',
    11: 'November',
    12: 'December'
}
df['Order Month'] = pd.to_datetime(df['Order Date']).dt.month.map(Months)
df['Order Month']
# Out:
# 0      November
# 1      February
# 2       January
# 3           May
# 4           May
#          ...
# 995         May
# 996    November
# 997     October
# 998    December
# 999       April
# Name: Order Month, Length: 1000, dtype: object

# %%
df
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount Order Date Day of the Week  \
# ...

# %%
df['Order Year'] = pd.to_datetime(df['Order Date']).dt.year
df['Order Year']
# Out:
# 0      2023
# 1      2023
# 2      2023
# 3      2023
# 4      2023
#        ...
# 995    2023
# 996    2023
# 997    2023
# 998    2023
# 999    2023
# Name: Order Year, Length: 1000, dtype: int32

# %%
df['Order Year'].value_counts().plot.bar(color='violet', figsize=(5, 3), width=0.8, edgecolor='black')

plt.title('Bar chart depicting the frequency of each year')
plt.xticks(rotation=0)
plt.show()

# %%
Seasons = {
    1: 'Winter', 2: 'Winter', 3: 'Winter',
    4: 'Spring', 5: 'Spring', 6: 'Spring',
    7: 'Summer', 8: 'Summer', 9: 'Summer',
    10: 'Fall', 11: 'Fall', 12: 'Fall'
}
df['Seasons'] = pd.to_datetime(df['Order Date']).dt.month.map(Seasons)
df['Seasons']
# Out:
# 0        Fall
# 1      Winter
# 2      Winter
# 3      Spring
# 4      Spring
#         ...
# 995    Spring
# 996      Fall
# 997      Fall
# 998      Fall
# 999    Spring
# Name: Seasons, Length: 1000, dtype: object

# %%
df
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount Order Date Day of the Week  \
# ...

# %%
df.set_index('Order Date', inplace=True)

# %%
df
# Out:
#             Transaction ID        Date Customer ID  Gender  Age  \
# Order Date
# 2023-11-24               1  2023-11-24     CUST001    Male   34
# 2023-02-27               2  2023-02-27     CUST002  Female   26
# 2023-01-13               3  2023-01-13     CUST003    Male   50
# 2023-05-21               4  2023-05-21     CUST004    Male   37
# 2023-05-06               5  2023-05-06     CUST005    Male   30
# ...                    ...         ...         ...     ...  ...
# 2023-05-16             996  2023-05-16     CUST996    Male   62
# 2023-11-17             997  2023-11-17     CUST997    Male   52
# 2023-10-29             998  2023-10-29     CUST998  Female   23
# 2023-12-05             999  2023-12-05     CUST999  Female   36
# 2023-04-12            1000  2023-04-12    CUST1000    Male   47
#
#            Product Category  Quantity  Price per Unit  Total Amount  \
# Order Date
# 2023-11-24           Beauty         3              50           150
# ...

# %% [raw]
# Correlation Analysis
#     1.	Compute the correlation matrix for numerical columns.
#     2.	Visualize the correlation matrix using a heatmap.
#     3.	Identify and discuss two key relationships from the heatmap.

# %% [raw]
# Correlation
#
# Is there a significant difference in the total amount spent between genders?

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Compute 'Total Spent' column (if not already present in the dataset)
# df['Total Spent'] = df['Quantity'] * df['Unit Price']

# Select numerical columns for correlation analysis
numerical_columns = df.select_dtypes(include=[np.number])  # Get only numeric columns
correlation_matrix = numerical_columns.corr()  # Compute the correlation matrix

# Plot the heatmap for the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# Analyze total spending by gender
total_spent_by_gender = df.groupby('Gender')['Total Amount'].mean()
print("Mean Total Spent by Gender:")
print(total_spent_by_gender)

# Violin plot to visualize the distribution of spending by gender
sns.violinplot(x='Gender', y='Total Amount', data=df, palette='pastel', legend=False)
plt.title('Total Spent Distribution by Gender')
plt.ylabel('Total Spent')
plt.xlabel('Gender')
plt.show()
# Out:
# Mean Total Spent by Gender:
# Gender
# Female    456.549020
# Male      455.428571
# Name: Total Amount, dtype: float64
# C:\Users\dines\AppData\Local\Temp\ipykernel_20724\2043412507.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Gender', y='Total Amount', data=df, palette='pastel', legend=False)

# %% [raw]
# How does the price per unit vary across different product categories?
# Draw a heatmap

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming the dataset has columns 'Product Category' and 'Unit Price'
# Group by Product Category and calculate the mean Unit Price
price_per_category = df.groupby('Product Category')['Price per Unit'].mean().reset_index()

# Pivot data for heatmap, set index and value (if more than one category dimension exists)
heatmap_data = price_per_category.pivot_table(index='Product Category', values='Price per Unit')

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Heatmap: Price Per Unit Across Product Categories')
plt.xlabel('Product Category')
plt.ylabel('Average Unit Price')
plt.show()

# %%
genders = {
    'Male': 1,
    'Female': 0
}
df['Gender_mapping'] = df['Gender'].map(genders)
df['Gender_mapping']
# Out:
# Order Date
# 2023-11-24    1
# 2023-02-27    0
# 2023-01-13    1
# 2023-05-21    1
# 2023-05-06    1
#              ..
# 2023-05-16    1
# 2023-11-17    1
# 2023-10-29    0
# 2023-12-05    0
# 2023-04-12    1
# Name: Gender_mapping, Length: 1000, dtype: int64

# %%
df
# Out:
#             Transaction ID        Date Customer ID  Gender  Age  \
# Order Date
# 2023-11-24               1  2023-11-24     CUST001    Male   34
# 2023-02-27               2  2023-02-27     CUST002  Female   26
# 2023-01-13               3  2023-01-13     CUST003    Male   50
# 2023-05-21               4  2023-05-21     CUST004    Male   37
# 2023-05-06               5  2023-05-06     CUST005    Male   30
# ...                    ...         ...         ...     ...  ...
# 2023-05-16             996  2023-05-16     CUST996    Male   62
# 2023-11-17             997  2023-11-17     CUST997    Male   52
# 2023-10-29             998  2023-10-29     CUST998  Female   23
# 2023-12-05             999  2023-12-05     CUST999  Female   36
# 2023-04-12            1000  2023-04-12    CUST1000    Male   47
#
#            Product Category  Quantity  Price per Unit  Total Amount  \
# Order Date
# 2023-11-24           Beauty         3              50           150
# ...

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount',
#        'Day of the Week', 'Order Month', 'Order Year', 'Seasons',
#        'Gender_mapping'],
#       dtype='object')

# %%
df.iloc[0:10, [df.columns.get_loc('Gender'), df.columns.get_loc('Product Category')]]
# Out:
#             Gender Product Category
# Order Date
# 2023-11-24    Male           Beauty
# 2023-02-27  Female         Clothing
# 2023-01-13    Male      Electronics
# 2023-05-21    Male         Clothing
# 2023-05-06    Male           Beauty
# 2023-04-25  Female           Beauty
# 2023-03-13    Male         Clothing
# 2023-02-22    Male      Electronics
# 2023-12-13    Male      Electronics
# 2023-10-07  Female         Clothing

# %%
# Extract sales data for a specific date (e.g., '2023-01-01')
specific_date_data = df.loc['2023-01-01']

# Display results
print(specific_date_data)
# Out:
#             Transaction ID        Date Customer ID  Gender  Age  \
# Order Date
# 2023-01-01             180  2023-01-01     CUST180    Male   41
# 2023-01-01             522  2023-01-01     CUST522    Male   46
# 2023-01-01             559  2023-01-01     CUST559  Female   40
#
#            Product Category  Quantity  Price per Unit  Total Amount  \
# Order Date
# 2023-01-01         Clothing         3             300           900
# 2023-01-01           Beauty         3             500          1500
# 2023-01-01         Clothing         4             300          1200
#
#            Day of the Week Order Month  Order Year Seasons  Gender_mapping
# Order Date
# 2023-01-01          Sunday     January        2023  Winter               1
# 2023-01-01          Sunday     January        2023  Winter               1
# 2023-01-01          Sunday     January        2023  Winter               0

# %%
import pandas as pd

# Assuming there is already a DataFrame 'df'

# Ensure the index is Datetime and sort it
df.index = pd.to_datetime(df.index)  # Convert index to DatetimeIndex if it isn't already
df = df.sort_index()  # Sort the index to ensure it is monotonic

# Perform the date-based slicing
date_range_data = df.loc['2023-01-01':'2023-01-10']

# Display results
print(date_range_data)
# Out:
#             Transaction ID        Date Customer ID  Gender  Age  \
# Order Date
# 2023-01-01             522  2023-01-01     CUST522    Male   46
# 2023-01-01             180  2023-01-01     CUST180    Male   41
# 2023-01-01             559  2023-01-01     CUST559  Female   40
# 2023-01-02             303  2023-01-02     CUST303    Male   19
# 2023-01-02             979  2023-01-02     CUST979  Female   19
# 2023-01-02             163  2023-01-02     CUST163  Female   64
# 2023-01-02             421  2023-01-02     CUST421  Female   37
# 2023-01-03             610  2023-01-03     CUST610  Female   26
# 2023-01-04             683  2023-01-04     CUST683    Male   38
# 2023-01-04             231  2023-01-04     CUST231  Female   23
# 2023-01-04              32  2023-01-04     CUST032    Male   30
# 2023-01-05             391  2023-01-05     CUST391    Male   19
# 2023-01-05             367  2023-01-05     CUST367  Female   57
# ...

# %%
# Extract all sales data for January 2023
january_data = df.loc['2023-01']
print(january_data)
# Out:
#             Transaction ID        Date Customer ID  Gender  Age  \
# Order Date
# 2023-01-01             522  2023-01-01     CUST522    Male   46
# 2023-01-01             180  2023-01-01     CUST180    Male   41
# 2023-01-01             559  2023-01-01     CUST559  Female   40
# 2023-01-02             303  2023-01-02     CUST303    Male   19
# 2023-01-02             979  2023-01-02     CUST979  Female   19
# ...                    ...         ...         ...     ...  ...
# 2023-01-30             322  2023-01-30     CUST322    Male   51
# 2023-01-30             329  2023-01-30     CUST329  Female   46
# 2023-01-31             235  2023-01-31     CUST235  Female   23
# 2023-01-31             300  2023-01-31     CUST300  Female   19
# 2023-01-31             964  2023-01-31     CUST964    Male   24
#
#            Product Category  Quantity  Price per Unit  Total Amount  \
# Order Date
# 2023-01-01           Beauty         3             500          1500
# ...

# %%
# Extract all sales data for the year 2023
year_data = df.loc['2023']
print(year_data)
# Out:
#             Transaction ID        Date Customer ID  Gender  Age  \
# Order Date
# 2023-01-01             522  2023-01-01     CUST522    Male   46
# 2023-01-01             180  2023-01-01     CUST180    Male   41
# 2023-01-01             559  2023-01-01     CUST559  Female   40
# 2023-01-02             303  2023-01-02     CUST303    Male   19
# 2023-01-02             979  2023-01-02     CUST979  Female   19
# ...                    ...         ...         ...     ...  ...
# 2023-12-29             908  2023-12-29     CUST908    Male   46
# 2023-12-29             520  2023-12-29     CUST520  Female   49
# 2023-12-29             233  2023-12-29     CUST233  Female   51
# 2023-12-29             805  2023-12-29     CUST805  Female   30
# 2023-12-31             857  2023-12-31     CUST857    Male   60
#
#            Product Category  Quantity  Price per Unit  Total Amount  \
# Order Date
# 2023-01-01           Beauty         3             500          1500
# ...

# %%
df.iloc[0:10]
# Out:
#             Transaction ID        Date Customer ID  Gender  Age  \
# Order Date
# 2023-01-01             522  2023-01-01     CUST522    Male   46
# 2023-01-01             180  2023-01-01     CUST180    Male   41
# 2023-01-01             559  2023-01-01     CUST559  Female   40
# 2023-01-02             303  2023-01-02     CUST303    Male   19
# 2023-01-02             979  2023-01-02     CUST979  Female   19
# 2023-01-02             163  2023-01-02     CUST163  Female   64
# 2023-01-02             421  2023-01-02     CUST421  Female   37
# 2023-01-03             610  2023-01-03     CUST610  Female   26
# 2023-01-04             683  2023-01-04     CUST683    Male   38
# 2023-01-04             231  2023-01-04     CUST231  Female   23
#
#            Product Category  Quantity  Price per Unit  Total Amount  \
# Order Date
# 2023-01-01           Beauty         3             500          1500
# 2023-01-01         Clothing         3             300           900
# ...

# %%
df.drop(columns=['Gender_mapping'], axis=1, inplace=True)

# %%
df
# Out:
#             Transaction ID        Date Customer ID  Gender  Age  \
# Order Date
# 2023-01-01             522  2023-01-01     CUST522    Male   46
# 2023-01-01             180  2023-01-01     CUST180    Male   41
# 2023-01-01             559  2023-01-01     CUST559  Female   40
# 2023-01-02             303  2023-01-02     CUST303    Male   19
# 2023-01-02             979  2023-01-02     CUST979  Female   19
# ...                    ...         ...         ...     ...  ...
# 2023-12-29             233  2023-12-29     CUST233  Female   51
# 2023-12-29             805  2023-12-29     CUST805  Female   30
# 2023-12-31             857  2023-12-31     CUST857    Male   60
# 2024-01-01             211  2024-01-01     CUST211    Male   42
# 2024-01-01             650  2024-01-01     CUST650    Male   55
#
#            Product Category  Quantity  Price per Unit  Total Amount  \
# Order Date
# 2023-01-01           Beauty         3             500          1500
# ...

# %%
df = df.iloc[2:]

# %%
df
# Out:
#             Transaction ID        Date Customer ID  Gender  Age  \
# Order Date
# 2023-01-01             559  2023-01-01     CUST559  Female   40
# 2023-01-02             303  2023-01-02     CUST303    Male   19
# 2023-01-02             979  2023-01-02     CUST979  Female   19
# 2023-01-02             163  2023-01-02     CUST163  Female   64
# 2023-01-02             421  2023-01-02     CUST421  Female   37
# ...                    ...         ...         ...     ...  ...
# 2023-12-29             233  2023-12-29     CUST233  Female   51
# 2023-12-29             805  2023-12-29     CUST805  Female   30
# 2023-12-31             857  2023-12-31     CUST857    Male   60
# 2024-01-01             211  2024-01-01     CUST211    Male   42
# 2024-01-01             650  2024-01-01     CUST650    Male   55
#
#            Product Category  Quantity  Price per Unit  Total Amount  \
# Order Date
# 2023-01-01         Clothing         4             300          1200
# ...
