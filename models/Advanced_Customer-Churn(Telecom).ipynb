# %% [markdown]
# # Project Title: Advanced Customer Churn Analysis - Telecom Industry

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"E:\Data-Analytics\data\churn-bigml-80.csv")
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.shape
# Out:
# (2666, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   2666 non-null   object
#  1   Account length          2666 non-null   int64
#  2   Area code               2666 non-null   int64
#  3   International plan      2666 non-null   object
#  4   Voice mail plan         2666 non-null   object
#  5   Number vmail messages   2666 non-null   int64
#  6   Total day minutes       2666 non-null   float64
#  7   Total day calls         2666 non-null   int64
#  8   Total day charge        2666 non-null   float64
#  9   Total eve minutes       2666 non-null   float64
#  10  Total eve calls         2666 non-null   int64
#  11  Total eve charge        2666 non-null   float64
#  12  Total night minutes     2666 non-null   float64
#  13  Total night calls       2666 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     2666.000000  2666.000000            2666.000000         2666.00000
# mean       100.620405   437.438860               8.021755          179.48162
# std         39.563974    42.521018              13.612277           54.21035
# min          1.000000   408.000000               0.000000            0.00000
# 25%         73.000000   408.000000               0.000000          143.40000
# 50%        100.000000   415.000000               0.000000          179.95000
# 75%        127.000000   510.000000              19.000000          215.90000
# max        243.000000   510.000000              50.000000          350.80000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      2666.000000       2666.000000        2666.000000      2666.000000
# mean        100.310203         30.512404         200.386159       100.023631
# ...

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(df['Total day minutes'], kde=True)
# Out:
# <Axes: xlabel='Total day minutes', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatterplot of Total Charge vs Account Length
sns.scatterplot(data=df, x="Account length", y="Total day charge", hue = 'Churn')
plt.title("Scatterplot of Total Day Charge vs Account Length")
plt.xlabel("Account Length (Days)")
plt.ylabel("Total Day Charge ($)")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatterplot of Total Charge vs Account Length
sns.scatterplot(data=df, x="Account length", y="Total eve charge", hue = 'Churn')
plt.title("Scatterplot of Total Charge vs Account Length")
plt.xlabel("Account Length (Days)")
plt.ylabel("Total Evening Charge ($)")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatterplot of Total Charge vs Account Length
sns.scatterplot(data=df, x="Account length", y="Total night charge", hue = 'Churn')
plt.title("Scatterplot of Total Charge vs Account Length")
plt.xlabel("Account Length (Days)")
plt.ylabel("Total Night Charge ($)")
plt.show()

# %%
sns.lmplot(data=df, x="Account length", y="Total day charge", ci=None, height=5, hue = 'Churn', col = 'Churn')

# %%
sns.lmplot(data=df, x="Account length", y="Total eve charge", ci=None, height=5, hue='Churn',col = 'Churn')

# %%
sns.lmplot(data=df, x="Account length", y="Total night charge", ci=None, height=5, hue='Churn',col = 'Churn')

# %%
correlation = df["Account length"].corr(df["Total day charge"])
print("Correlation between Account Length and Total day Charge:", correlation)
# Out:
# Correlation between Account Length and Total day Charge: 0.0028434870061192605

# %%
correlation = df["Account length"].corr(df["Total eve charge"])
print("Correlation between Account Length and Total evening Charge:", correlation)
# Out:
# Correlation between Account Length and Total evening Charge: -0.015909313892513027

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select the two columns
columns_of_interest = df[["Account length", "Total day charge"]]

# Compute the correlation matrix
correlation_matrix = columns_of_interest.corr()

# Plot the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Heatmap of Correlation Between Account Length and Total Day Charge")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select the two columns
columns_of_interest = df[["Account length", "Total eve charge"]]

# Compute the correlation matrix
correlation_matrix = columns_of_interest.corr()

# Plot the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Heatmap of Correlation Between Account Length and Total evening Charge")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select the two columns
columns_of_interest = df[["Account length", "Total night charge"]]

# Compute the correlation matrix
correlation_matrix = columns_of_interest.corr()

# Plot the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Heatmap of Correlation Between Account Length and Total Night Charge")
plt.show()

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df['International plan'].value_counts()
# Out:
# International plan
# No     2396
# Yes     270
# Name: count, dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# Churn
# False    2278
# True      388
# Name: count, dtype: int64

# %%
df['Voice mail plan'].value_counts()
# Out:
# Voice mail plan
# No     1933
# Yes     733
# Name: count, dtype: int64

# %%
df['monthly_charge'] = (df['Total day charge'] + df['Total eve charge'] + df['Total night charge'] + df['Total intl charge'])*30

# %%
df['Customer service calls'].mean()
# Out:
# 1.5626406601650413

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     2666.000000  2666.000000            2666.000000         2666.00000
# mean       100.620405   437.438860               8.021755          179.48162
# std         39.563974    42.521018              13.612277           54.21035
# min          1.000000   408.000000               0.000000            0.00000
# 25%         73.000000   408.000000               0.000000          143.40000
# 50%        100.000000   415.000000               0.000000          179.95000
# 75%        127.000000   510.000000              19.000000          215.90000
# max        243.000000   510.000000              50.000000          350.80000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      2666.000000       2666.000000        2666.000000      2666.000000
# mean        100.310203         30.512404         200.386159       100.023631
# ...

# %%
sns.scatterplot(data=df, x="Total intl calls", y="Total intl charge", hue = 'Churn', style = 'International plan')
# Out:
# <Axes: xlabel='Total intl calls', ylabel='Total intl charge'>

# %%
sns.lmplot(data=df, x="Total intl calls", y="Total intl charge", ci=None, height=5, hue = 'Churn', col = 'International plan')

# %%
sns.scatterplot(data=df, x="Total intl calls", y="Total intl charge", hue = 'Churn', style = 'International plan')
# Out:
# <Axes: xlabel='Total intl calls', ylabel='Total intl charge'>

# %%
sns.lmplot(data=df, x="Account length", y="Total intl charge", ci=None, height=5, hue = 'Churn', col = 'International plan')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='International plan', y='', data=df)
plt.title('Total Day Minutes vs Churn')
plt.show()
# Out:
# C:\Users\dines\AppData\Local\Temp\ipykernel_16448\1221431710.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Churn', y='Total day minutes', data=df, palette='coolwarm', linewidth=2)
